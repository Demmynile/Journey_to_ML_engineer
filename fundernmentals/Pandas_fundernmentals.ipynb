# %% [markdown]
# <a href="https://colab.research.google.com/github/Demmynile/Journey_to_ML_engineer/blob/main/Pandas_fundernmentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# create a dataframe

# %%
data = [
    ['Nissan' , 'Stanza', 1991 , 138 , 4, 'MANUAL', 'sedan' ,2000],
    ['Hyundai', 'Sonata' , 2017, None , 4 , 'AUTOMATIC' , 'Sedan', 27150],
    ['Lotus' , 'Elise' , 2010 , 218 , 4, 'MANUAL' , 'convertible', 54990],
    ['GMC', 'Acadia', 2017 , 194 ,4,'AUTOMATIC' , '4dr SUV', 34450],
    ['Nissan' , 'Frontier' , 2017 , 261 ,6, 'MANUAL', 'Pickup' , 32340]
]

columns = [
    'Make' , 'Model' , 'Year', 'Engine HP' , 'Engine Cylinders',
    'Transimission Type' , 'Vehicle_Style' , 'MSRP'
]

# %%
df = pd.DataFrame(data , columns = columns)

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 0   Nissan    Stanza  1991      138.0                 4             MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4          AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4             MANUAL
# 3      GMC    Acadia  2017      194.0                 4          AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6             MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head(5)
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 0   Nissan    Stanza  1991      138.0                 4             MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4          AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4             MANUAL
# 3      GMC    Acadia  2017      194.0                 4          AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6             MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head(2)
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 0   Nissan  Stanza  1991      138.0                 4             MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4          AUTOMATIC
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150

# %% [markdown]
# Create a series

# %%
df.Make
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %%
df['Make']
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: object

# %% [markdown]
# for whitespaces df[''] is suitable

# %% [markdown]
# for multiple cases df[[[]]]

# %%
df[['Make' , 'Model' , 'MSRP']]
# Out:
#       Make     Model   MSRP
# 0   Nissan    Stanza   2000
# 1  Hyundai    Sonata  27150
# 2    Lotus     Elise  54990
# 3      GMC    Acadia  34450
# 4   Nissan  Frontier  32340

# %% [markdown]
# for adding to the existing dataframe

# %%
df['id'] = [1 ,2,3,4,5]

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 0   Nissan    Stanza  1991      138.0                 4             MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4          AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4             MANUAL
# 3      GMC    Acadia  2017      194.0                 4          AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6             MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000   1
# 1         Sedan  27150   2
# 2   convertible  54990   3
# 3       4dr SUV  34450   4
# 4        Pickup  32340   5

# %% [markdown]
# deleting a column

# %%
del df['id']

# %%
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 0   Nissan    Stanza  1991      138.0                 4             MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4          AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4             MANUAL
# 3      GMC    Acadia  2017      194.0                 4          AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6             MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.Make.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.loc[1]
# Out:
# Make                    Hyundai
# Model                    Sonata
# Year                       2017
# Engine HP                   NaN
# Engine Cylinders              4
# Transimission Type    AUTOMATIC
# Vehicle_Style             Sedan
# MSRP                      27150
# Name: 1, dtype: object

# %% [markdown]
# Accessing Elements

# %%
df.loc[[1,2]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 1  Hyundai  Sonata  2017        NaN                 4          AUTOMATIC
# 2    Lotus   Elise  2010      218.0                 4             MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 2   convertible  54990

# %%
df.iloc[[1,2]]
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 1  Hyundai  Sonata  2017        NaN                 4          AUTOMATIC
# 2    Lotus   Elise  2010      218.0                 4             MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 2   convertible  54990

# %%
df.reset_index(drop = True)
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 0   Nissan    Stanza  1991      138.0                 4             MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4          AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4             MANUAL
# 3      GMC    Acadia  2017      194.0                 4          AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6             MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %% [markdown]
# Element-wise operations

# %%
df['Engine HP']/100
# Out:
# 0    1.38
# 1     NaN
# 2    2.18
# 3    1.94
# 4    2.61
# Name: Engine HP, dtype: float64

# %%
df['Engine HP'] * 2
# Out:
# 0    276.0
# 1      NaN
# 2    436.0
# 3    388.0
# 4    522.0
# Name: Engine HP, dtype: float64

# %%
df["Year"] >= 2015
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Year, dtype: bool

# %% [markdown]
# Filtering

# %%
df[df["Year"] >= 2015]
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 1  Hyundai    Sonata  2017        NaN                 4          AUTOMATIC
# 3      GMC    Acadia  2017      194.0                 4          AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6             MANUAL
#
#   Vehicle_Style   MSRP
# 1         Sedan  27150
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df[(df["Make"] == 'Nissan') & (df["Year"] >= 2015) ]
# Out:
#      Make     Model  Year  Engine HP  Engine Cylinders Transimission Type  \
# 4  Nissan  Frontier  2017      261.0                 6             MANUAL
#
#   Vehicle_Style   MSRP
# 4        Pickup  32340

# %% [markdown]
# String Operations

# %%
df["Vehicle_Style"]
# Out:
# 0          sedan
# 1          Sedan
# 2    convertible
# 3        4dr SUV
# 4         Pickup
# Name: Vehicle_Style, dtype: object

# %%
df["Vehicle_Style"].str.lower()
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr suv
# 4         pickup
# Name: Vehicle_Style, dtype: object

# %%
df["Vehicle_Style"].str.replace(" " , "_").str.lower()
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr_suv
# 4         pickup
# Name: Vehicle_Style, dtype: object

# %%
df["Vehicle_Style"] = df["Vehicle_Style"].str.replace(" " , "_").str.lower()

# %%
df["Vehicle_Style"]
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr_suv
# 4         pickup
# Name: Vehicle_Style, dtype: object

# %% [markdown]
# Summarizing Operators

# %%
df.MSRP.max()
# Out:
# 54990

# %%
df.describe().round(2)
# Out:
#           Year  Engine HP  Engine Cylinders      MSRP
# count     5.00       4.00              5.00      5.00
# mean   2010.40     202.75              4.40  30186.00
# std      11.26      51.30              0.89  18985.04
# min    1991.00     138.00              4.00   2000.00
# 25%    2010.00     180.00              4.00  27150.00
# 50%    2017.00     206.00              4.00  32340.00
# 75%    2017.00     228.75              4.00  34450.00
# max    2017.00     261.00              6.00  54990.00

# %%
df.Make.unique()
# Out:
# array(['Nissan', 'Hyundai', 'Lotus', 'GMC'], dtype=object)

# %%
df.nunique()
# Out:
# Make                  4
# Model                 5
# Year                  3
# Engine HP             4
# Engine Cylinders      2
# Transimission Type    2
# Vehicle_Style         4
# MSRP                  5
# dtype: int64

# %% [markdown]
# Missing Values

# %%
df.isnull()
# Out:
#     Make  Model   Year  Engine HP  Engine Cylinders  Transimission Type  \
# 0  False  False  False      False             False               False
# 1  False  False  False       True             False               False
# 2  False  False  False      False             False               False
# 3  False  False  False      False             False               False
# 4  False  False  False      False             False               False
#
#    Vehicle_Style   MSRP
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False

# %%
df.Make.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine HP             1
# Engine Cylinders      0
# Transimission Type    0
# Vehicle_Style         0
# MSRP                  0
# dtype: int64

# %% [markdown]
# Grouping

# %%
df.groupby('Transimission Type').MSRP.max()
# Out:
# Transimission Type
# AUTOMATIC    34450
# MANUAL       54990
# Name: MSRP, dtype: int64

# %%
df.groupby("Model").Year.max()
# Out:
# Model
# Acadia      2017
# Elise       2010
# Frontier    2017
# Sonata      2017
# Stanza      1991
# Name: Year, dtype: int64

# %% [markdown]
# Arrays and Numpy of the data

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %%
df.to_dict(orient='records')
# Out:
# [{'Make': 'Nissan',
#   'Model': 'Stanza',
#   'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transimission Type': 'MANUAL',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 2000},
#  {'Make': 'Hyundai',
#   'Model': 'Sonata',
#   'Year': 2017,
#   'Engine HP': nan,
#   'Engine Cylinders': 4,
#   'Transimission Type': 'AUTOMATIC',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 27150},
#  {'Make': 'Lotus',
#   'Model': 'Elise',
#   'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transimission Type': 'MANUAL',
#   'Vehicle_Style': 'convertible',
#   'MSRP': 54990},
#  {'Make': 'GMC',
#   'Model': 'Acadia',
#   'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transimission Type': 'AUTOMATIC',
#   'Vehicle_Style': '4dr_suv',
#   'MSRP': 34450},
#  {'Make': 'Nissan',
#   'Model': 'Frontier',
#   'Year': 2017,
#   'Engine HP': 261.0,
#   'Engine Cylinders': 6,
#   'Transimission Type': 'MANUAL',
#   'Vehicle_Style': 'pickup',
# ...
